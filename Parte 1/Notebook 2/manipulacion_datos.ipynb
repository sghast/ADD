# %% [markdown]
# # **Introducción a la manipulación de datos con Pandas**
#
# 1. Acceso nativo a dataframes
#
# 2. Indexado en pandas
#
# 3. Manipulación de índices
#
# 4. Selección condicional de datos
#
# 5. Asignación de datos
#
# <img src="../imgs/foto-dia-02.png" width="450px" height="300px">

# %% [markdown]
# Seleccionar valores específicos de un pandas **DataFrame** o **Series** para trabajar sobre ellos es un paso implícito en casi cualquier operación de datos que se vaya a ejecutar, por lo que una de las primeras cosas que se necesita aprender al trabajar con datos en Python es cómo ir seleccionando los puntos de datos relevantes para nuestro trabajo de forma rápida y efectiva.

# %%
import pandas as pd

reviews = pd.read_csv('datasets/reviews-vinos.csv',
                      index_col=0)
pd.set_option('display.max_rows', 5)

# %% [markdown]
# ### **1. Acceso nativo a los dataframes**

# %% [markdown]
# Los objetos nativos de Python proporcionan buenas formas de indexar datos. Pandas integra todos estos, lo que ayuda a que sea fácil empezar con él.
#
# Empezamos con este DataFrame:

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# En Python, podemos acceder a la propiedad de un objeto accediendo a ella como un atributo. Un objeto libro, por ejemplo, puede tener un atributo título, a la que podemos acceder llamando a **libro.título**. Las columnas de un DataFrame de pandas funcionan de forma muy parecida.
#
# Así, para acceder a los datos de la columna país del dataframe de reseñas podemos utilizar:

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: str

# %% [markdown]
# Si tenemos un diccionario Python, podemos acceder a sus valores utilizando el operador de indexación ([]). Podemos hacer lo mismo con las columnas de un DataFrame:

# %%
reviews['country']
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: str

# %% [markdown]
# Estas son las dos formas de seleccionar una Serie concreta de un DataFrame. Ninguna de ellas es más o menos válida sintácticamente que la otra, pero el operador de indexación [] tiene la ventaja de que puede manejar nombres de columnas con caracteres reservados (por ejemplo, si tuviéramos una columna ciudad país, reviews.ciudadpaís no funcionaría).

# %% [markdown]
# ¿No se parece una serie de pandas a una lista? Lo es, así que no es de extrañar que, para profundizar en un valor específico, sólo tengamos que utilizar el operador de indexación [] una vez más:

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# ### **2. Indexado en pandas**

# %% [markdown]
# El operador de indexación y la selección de atributos son agradables porque funcionan igual que en el resto del ecosistema Python. Como principiante, esto hace que sean fáciles de aprender y usar. Sin embargo, pandas tiene sus propios operadores de acceso, loc e iloc. Para operaciones más avanzadas, estos son los que se supone que debes usar.

# %% [markdown]
# ##### **2.1 Selección basada en posiciones**

# %% [markdown]
# La indexación en Pandas funciona en uno de dos paradigmas. El primero es la selección basada en índices: seleccionar datos basándose en su posición numérica en los datos. iloc sigue este paradigma.
#
# Para seleccionar la primera fila de datos en un DataFrame, podemos usar lo siguiente:

# %%
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %% [markdown]
# En el ejemplo anterior el tipo de datos que nos devuelve es una serie de pandas si queremos que nos devuelva en formato dataframe podemos hacer lo siguiente:

# %%
reviews.iloc[[0]]
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %% [markdown]
# La indexación se realiza primero por filas y luego por columnas, en este siguiente ejemplo se seleccionan todas los valores de todas las filas pero sólo de la primera columna.

# %%
reviews.iloc[:,0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: str

# %% [markdown]
# Por sí solo, el operador :, que procede del Python nativo, significa "todo". Sin embargo, cuando se combina con otros selectores, puede utilizarse para indicar un rango de valores. Por ejemplo, para seleccionar las tres primeras columnas sólo de la primera, segunda y tercera fila, haríamos:

# %%
reviews.iloc[:3,:3]
# Out:
#     country                                        description   designation
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN

# %% [markdown]
# También podemos hacer algo muy potente que es el indexado basado en funciones lambda, por ejemplo, si sólo queremos las filas que tienen el índice par podemos hacerlo de la siguiente manera:

# %%
reviews.iloc[lambda reviews : reviews.index % 2 == 0]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 2           US  Tart and snappy, the flavors of lime flesh and...
# ...        ...                                                ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 2                                 NaN      87   14.0             Oregon
# ...                               ...     ...    ...                ...
# 129968                          Kritt      90   30.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#                  region_1           region_2    taster_name  \
# 0                    Etna                NaN  Kerin O’Keefe
# 2       Willamette Valley  Willamette Valley   Paul Gregutt
# ...                   ...                ...            ...
# 129968             Alsace                NaN     Roger Voss
# 129970             Alsace                NaN     Roger Voss
#
#        taster_twitter_handle  \
# 0               @kerinokeefe
# 2                @paulgwine
# ...                      ...
# 129968            @vossroger
# 129970            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# ...                                                   ...             ...
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                   winery
# 0                Nicosia
# 2              Rainstorm
# ...                  ...
# 129968   Domaine Gresser
# 129970  Domaine Schoffit
#
# [64986 rows x 13 columns]

# %% [markdown]
# Una forma muy útil es el indexado con listas, como en el siguiente ejemplo:

# %%
reviews.iloc[[1,2], [1,3]]
# Out:
#                                          description  points
# 1  This is ripe and fruity, a wine that is smooth...      87
# 2  Tart and snappy, the flavors of lime flesh and...      87

# %% [markdown]
# Por último, conviene saber que se pueden utilizar números negativos en la selección. Esto comenzará a contar hacia adelante desde el final de los valores. Así, por ejemplo, aquí están los últimos cinco elementos del conjunto de datos.

# %%
reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# 129966      NaN           NaN  Anna Lee C. Iijima                   NaN
# 129967   Oregon  Oregon Other        Paul Gregutt           @paulgwine
# 129968   Alsace           NaN          Roger Voss            @vossroger
# 129969   Alsace           NaN          Roger Voss            @vossroger
# 129970   Alsace           NaN          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit

# %% [markdown]
# ##### **2.2 Selección basada en índices/etiquetas**

# %% [markdown]
# El segundo paradigma para la selección de atributos es el que sigue el operador loc: la selección basada en etiquetas. En este paradigma, lo que importa es el valor del índice del dato, no su posición.
#
# Por ejemplo, para obtener el valor del primer índice para la columna country, ahora haríamos lo siguiente:

# %%
reviews.loc[0,'country']
# Out:
# 'Italy'

# %% [markdown]
# iloc es conceptualmente más sencillo que loc porque ignora los índices del conjunto de datos. Cuando usamos iloc tratamos el conjunto de datos como una gran matriz (una lista de listas), en la que tenemos que indexar por posición. loc, por el contrario, usa la información de los índices para hacer su trabajo. Dado que el conjunto de datos suele tener índices significativos, suele ser más fácil hacer las cosas con loc. Por ejemplo, aquí hay una operación que es mucho más fácil usando loc, ya que podemos especificar el nombre de las columnas.

# %%
reviews.loc[0:99,['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#        taster_name taster_twitter_handle  points
# 0    Kerin O’Keefe          @kerinokeefe      87
# 1       Roger Voss            @vossroger      87
# ..             ...                   ...     ...
# 98   Kerin O’Keefe          @kerinokeefe      88
# 99  Virginie Boone               @vboone      88
#
# [100 rows x 3 columns]

# %% [markdown]
# A la hora de elegir entre loc e iloc, hay que tener en cuenta que ambos métodos utilizan esquemas de indexación ligeramente diferentes.
#
# iloc utiliza el esquema de indexación de Python, donde se incluye el primer elemento del rango y se excluye el último. Así, 0:10 seleccionará las entradas 0,...,9. loc, por su parte, indexa de forma inclusiva. Así, 0:10 seleccionará las entradas 0,...,10.
#
# Esto es especialmente confuso cuando el índice del DataFrame es una simple lista numérica, por ejemplo 0,...,1000. En este caso df.iloc[0:1000] devolverá 1000 entradas, ¡mientras que df.loc[0:1000] devolverá 1001 de ellas! Para obtener 1000 elementos utilizando loc, tendrá que ir un poco más abajo y pedir df.loc[0:999].
#
# Por lo demás, la semántica del uso de loc es la misma que la de iloc.

# %% [markdown]
# ### **3. Manipulación de índices**

# %% [markdown]
# La selección basada en etiquetas deriva su potencia de las etiquetas del índice. El índice que utilizamos no es inmutable. Podemos manipular el índice de la forma que creamos conveniente.
#
# El método set_index() puede ser utilizado para hacer el trabajo. Esto es lo que ocurre cuando establecemos_index en el campo country:

# %%
reviews = reviews.set_index("country").sort_index()

reviews.loc['Argentina': 'France', 'title']

reviews = reviews.reset_index()

# %% [markdown]
# Esto resulta útil si se puede establecer un índice para el conjunto de datos que sea mejor que el actual.

# %% [markdown]
# ### **4. Selección condicional de datos**

# %% [markdown]
# Hasta ahora hemos estado indexando varios tramos de datos, utilizando propiedades estructurales del propio DataFrame. Sin embargo, para hacer cosas interesantes con los datos, a menudo necesitamos hacer preguntas basadas en condiciones.
#
# Por ejemplo, supongamos que estamos interesados específicamente en los vinos mejores que la media producidos en Italia.
#
# Podemos empezar comprobando si cada vino es italiano o no:

# %%
reviews.country == 'Ecuador'
# Out:
# 0         False
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %% [markdown]
# Esta operación produce una serie de booleanos Verdadero/Falso en función del país de cada registro. Este resultado puede utilizarse dentro de loc para seleccionar los datos pertinentes

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#       country                                        description designation  \
# 40042   Italy  Rose, violet, iris and red berry aromas lead t...     Baruffo
# 40043   Italy  This elegant Nebbiolo delivers the grape's cla...         NaN
# ...       ...                                                ...         ...
# 59580   Italy  Kerner is an aromatic white grape cross bred i...         NaN
# 59581   Italy  This is dominated by oak and oak-driven aromas...       Rosso
#
#        points  price            province          region_1 region_2  \
# 40042      92   22.0             Tuscany  Chianti Classico      NaN
# 40043      92   26.0            Piedmont            Langhe      NaN
# ...       ...    ...                 ...               ...      ...
# 59580      88   20.0  Northeastern Italy        Alto Adige      NaN
# 59581      87    NaN   Sicily & Sardinia              Etna      NaN
#
#          taster_name taster_twitter_handle  \
# 40042  Kerin O’Keefe          @kerinokeefe
# 40043  Kerin O’Keefe          @kerinokeefe
# ...              ...                   ...
# 59580            NaN                   NaN
# 59581  Kerin O’Keefe          @kerinokeefe
#
#                                                    title            variety  \
# 40042  Cantalici L'Antica Fornace di Ridolfo 2011 Bar...         Sangiovese
# 40043               Paolo Scavino 2012 Nebbiolo (Langhe)           Nebbiolo
# ...                                                  ...                ...
# 59580      Abbazia di Novacella 2011 Kerner (Alto Adige)             Kerner
# 59581             Masseria Setteporte 2012 Rosso  (Etna)  Nerello Mascalese
#
#                                       winery
# 40042  Cantalici L'Antica Fornace di Ridolfo
# 40043                          Paolo Scavino
# ...                                      ...
# 59580                   Abbazia di Novacella
# 59581                    Masseria Setteporte
#
# [19540 rows x 13 columns]

# %% [markdown]
# Este DataFrame tiene ~20.000 filas. El original tenía ~130.000. Eso significa que alrededor del 15% de los vinos proceden de Italia.
#
# También queríamos saber cuáles son mejores que la media. Los vinos se evalúan en una escala de 80 a 100 puntos, por lo que podríamos referirnos a los vinos que obtuvieron al menos 90 puntos.
#
# Podemos utilizar el símbolo ampersand (&) para unir las dos preguntas:

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#       country                                        description  \
# 40042   Italy  Rose, violet, iris and red berry aromas lead t...
# 40043   Italy  This elegant Nebbiolo delivers the grape's cla...
# ...       ...                                                ...
# 59575   Italy  Made with 50% Merlot, 30% Cabernet Franc and 2...
# 59576   Italy  Red berry, rose and a sprinkling of baking spi...
#
#                   designation  points  price  province          region_1  \
# 40042                 Baruffo      92   22.0   Tuscany  Chianti Classico
# 40043                     NaN      92   26.0  Piedmont            Langhe
# ...                       ...     ...    ...       ...               ...
# 59575                   Rosso      90   32.0   Tuscany          Bolgheri
# 59576  del Comune di La Morra      91   44.0  Piedmont            Barolo
#
#       region_2    taster_name taster_twitter_handle  \
# 40042      NaN  Kerin O’Keefe          @kerinokeefe
# 40043      NaN  Kerin O’Keefe          @kerinokeefe
# ...        ...            ...                   ...
# 59575      NaN  Kerin O’Keefe          @kerinokeefe
# 59576      NaN  Kerin O’Keefe          @kerinokeefe
#
#                                                    title     variety  \
# 40042  Cantalici L'Antica Fornace di Ridolfo 2011 Bar...  Sangiovese
# 40043               Paolo Scavino 2012 Nebbiolo (Langhe)    Nebbiolo
# ...                                                  ...         ...
# 59575                Le Macchiole 2013 Rosso  (Bolgheri)   Red Blend
# 59576  Ciabot Berton 2012 del Comune di La Morra  (Ba...    Nebbiolo
#
#                                       winery
# 40042  Cantalici L'Antica Fornace di Ridolfo
# 40043                          Paolo Scavino
# ...                                      ...
# 59575                           Le Macchiole
# 59576                          Ciabot Berton
#
# [6648 rows x 13 columns]

# %% [markdown]
# Supongamos que queremos comprar cualquier vino elaborado en Italia o que tenga una calificación superior a 90. Para ello utilizamos el carácter de tubería (|):

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points > 90)]
# Out:
#           country                                        description  \
# 11      Argentina  Pure on the nose, with plenty of pop. Aromas o...
# 12      Argentina  This single-vineyard Malbec proves once again ...
# ...           ...                                                ...
# 129964        NaN  Dark ruby in the glass, this wine offers a bou...
# 129970        NaN  This wine offers a delightful bouquet of black...
#
#                 designation  points  price          province region_1  \
# 11      Selección de Bodega      91   40.0  Mendoza Province  Mendoza
# 12            Finca Mirador      91  120.0  Mendoza Province  Mendoza
# ...                     ...     ...    ...               ...      ...
# 129964             M Series      92   36.0               NaN      NaN
# 129970                  NaN      91   32.0               NaN      NaN
#
#        region_2        taster_name taster_twitter_handle  \
# 11          NaN  Michael Schachner           @wineschach
# 12          NaN                NaN                   NaN
# ...         ...                ...                   ...
# 129964      NaN      Mike DeSimone        @worldwineguys
# 129970      NaN      Mike DeSimone        @worldwineguys
#
#                                                     title         variety  \
# 11      Doña Paula 2007 Selección de Bodega Malbec (Me...          Malbec
# 12      Achaval-Ferrer 2008 Finca Mirador Malbec (Mend...          Malbec
# ...                                                   ...             ...
# 129964                Psagot 2013 M Series Cabernet Franc  Cabernet Franc
# 129970                                 Psagot 2014 Merlot          Merlot
#
#                 winery
# 11          Doña Paula
# 12      Achaval-Ferrer
# ...                ...
# 129964          Psagot
# 129970          Psagot
#
# [48910 rows x 13 columns]

# %% [markdown]
# Pandas viene con unos cuantos selectores condicionales incorporados, dos de los cuales destacaremos aquí.
#
# El primero es isin. isin permite seleccionar datos cuyo valor "está en" una lista de valores. Por ejemplo, así es como podemos usarlo para seleccionar vinos sólo de Italia o Francia:

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#       country                                        description  designation  \
# 14572  France  This light and fruity wine, produced by a Burg...  La Perlière
# 14573  France  The fruit is extremely extracted, making for a...          NaN
# ...       ...                                                ...          ...
# 59580   Italy  Kerner is an aromatic white grape cross bred i...          NaN
# 59581   Italy  This is dominated by oak and oak-driven aromas...        Rosso
#
#        points  price            province             region_1 region_2  \
# 14572      84   15.0          Beaujolais  Beaujolais-Villages      NaN
# 14573      83   17.0            Bordeaux   Bordeaux Supérieur      NaN
# ...       ...    ...                 ...                  ...      ...
# 59580      88   20.0  Northeastern Italy           Alto Adige      NaN
# 59581      87    NaN   Sicily & Sardinia                 Etna      NaN
#
#          taster_name taster_twitter_handle  \
# 14572     Roger Voss            @vossroger
# 14573     Roger Voss            @vossroger
# ...              ...                   ...
# 59580            NaN                   NaN
# 59581  Kerin O’Keefe          @kerinokeefe
#
#                                                    title  \
# 14572  Maison Jean-Baptiste Béjot 2014 La Perlière  (...
# 14573            Château Damase 2012  Bordeaux Supérieur
# ...                                                  ...
# 59580      Abbazia di Novacella 2011 Kerner (Alto Adige)
# 59581             Masseria Setteporte 2012 Rosso  (Etna)
#
#                         variety                      winery
# 14572                     Gamay  Maison Jean-Baptiste Béjot
# 14573  Bordeaux-style Red Blend              Château Damase
# ...                         ...                         ...
# 59580                    Kerner        Abbazia di Novacella
# 59581         Nerello Mascalese         Masseria Setteporte
#
# [41633 rows x 13 columns]

# %% [markdown]
# El segundo es isnull (y su compañero notnull). Estos métodos permiten resaltar los valores que están (o no) vacíos (NaN). Por ejemplo, para filtrar los vinos que carecen de etiqueta de precio en el conjunto de datos, esto es lo que haríamos:

# %%
reviews.loc[reviews.price.isnull()]
# Out:
#           country                                        description  \
# 63      Argentina  An aggressive, forceful blend of one-third eac...
# 66      Argentina  Earthy, woodsy aromas of black plum are robust...
# ...           ...                                                ...
# 129917        NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 129937        NaN  Winemaker: Gordon Newton Johnson. This is such...
#
#                                     designation  points  price  \
# 63            Libertad Vineyards Finca Libertad      87    NaN
# 66                                      Reserve      89    NaN
# ...                                         ...     ...    ...
# 129917  Cape Winemakers Guild Vloekskoot Wooded      91    NaN
# 129937          Cape Winemakers Guild Windansea      92    NaN
#
#                 province    region_1 region_2        taster_name  \
# 63      Mendoza Province     Mendoza      NaN  Michael Schachner
# 66      Mendoza Province  Uco Valley      NaN  Michael Schachner
# ...                  ...         ...      ...                ...
# 129917               NaN         NaN      NaN      Lauren Buzzeo
# 129937               NaN         NaN      NaN      Lauren Buzzeo
#
#        taster_twitter_handle  \
# 63               @wineschach
# 66               @wineschach
# ...                      ...
# 129917             @laurbuzz
# 129937             @laurbuzz
#
#                                                     title  \
# 63      Benegas 2008 Libertad Vineyards Finca Libertad...
# 66               Menduco 2014 Reserve Malbec (Uco Valley)
# ...                                                   ...
# 129917  Bartho Eksteen 2016 Cape Winemakers Guild Vloe...
# 129937  Newton Johnson 2016 Cape Winemakers Guild Wind...
#
#                          variety          winery
# 63      Bordeaux-style Red Blend         Benegas
# 66                        Malbec         Menduco
# ...                          ...             ...
# 129917           Sauvignon Blanc  Bartho Eksteen
# 129937                Pinot Noir  Newton Johnson
#
# [8996 rows x 13 columns]

# %% [markdown]
# ### **5. Asignación de datos**

# %% [markdown]
# Por otro lado, asignar datos a un DataFrame es fácil. Puede asignar un valor constante:

# %%
reviews['critica'] = 'me gusta'
reviews['critica']
# Out:
# 0         me gusta
# 1         me gusta
#             ...
# 129969    me gusta
# 129970    me gusta
# Name: critica, Length: 129971, dtype: str

# %% [markdown]
# O con valores iterables:

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64

# %% [markdown]
# También podemos utilizar el loc junto con condicionales para hacer asignaciones de valores:

# %%
reviews.loc[reviews.price.isnull()] = 0
reviews.loc[reviews.price == 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 reviews.loc[reviews.price.isnull()] = 0
#       2 reviews.loc[reviews.price == 0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
#    1955     self._setitem_single_block(indexer, value, name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexing.py:2044, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2041 else:
#    2042     # scalar value
#    2043     for loc in ilocs:
# -> 2044         self._setitem_single_column(loc, value, pi)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexing.py:2181, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2171 if dtype == np.void:
#    2172     # This means we're expanding, with multiple columns, e.g.
#    2173     #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)   2176     # Here, we replace those temporary `np.void` columns with
#    2177     # columns of the appropriate dtype, based on `value`.
#    2178     self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2179         value, len(self.obj)
#    2180     )
# -> 2181 self.obj._mgr.column_setitem(loc, plane_indexer, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\managers.py:1503, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1501     col_mgr.setitem_inplace(idx, value)
#    1502 else:
# -> 1503     new_mgr = col_mgr.setitem((idx,), value)
#    1504     self.iset(loc, new_mgr._block.values, inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\managers.py:604, in BaseBlockManager.setitem(self, indexer, value)
#     600     # No need to split if we either set all columns or on a single block
#     601     # manager
#     602     self = self.copy(deep=True)
# --> 604 return self.apply("setitem", indexer=indexer, value=value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\blocks.py:1667, in EABackedBlock.setitem(self, indexer, value)
#    1664 check_setitem_lengths(indexer, value, values)
#    1666 try:
# -> 1667     values[indexer] = value
#    1668 except (ValueError, TypeError):
#    1669     if isinstance(self.dtype, IntervalDtype):
#    1670         # see TestSetitemFloatIntervalWithIntIntervalValues
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arrays\string_.py:863, in StringArray.__setitem__(self, key, value)
#     860 if self._readonly:
#     861     raise ValueError("Cannot modify read-only array")
# --> 863 value = self._maybe_convert_setitem_value(value)
#     865 key = check_array_indexer(self, key)
#     866 scalar_key = lib.is_scalar(key)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arrays\string_.py:837, in StringArray._maybe_convert_setitem_value(self, value)
#     835         value = self.dtype.na_value
#     836     elif not isinstance(value, str):
# --> 837         raise TypeError(
#     838             f"Invalid value '{value}' for dtype '{self.dtype}'. Value should "
#     839             f"be a string or missing value, got '{type(value).__name__}' "
#     840             "instead."
#     841         )
#     842 else:
#     843     value = extract_array(value, extract_numpy=True)
#
# TypeError: Invalid value '0' for dtype 'str'. Value should be a string or missing value, got 'int' instead.
